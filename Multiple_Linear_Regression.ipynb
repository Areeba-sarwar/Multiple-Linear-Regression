# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
data={
    "Area": [1200,1500,1800,2500,2000],
    "Bedrooms": [2,3,3,4,5],
    "Age": [10,5,8,2,1],
    "Price": [240000, 300000, 500000, 600000, 700000]
}

# %%
df= pd.DataFrame(data)

# %%
x= df[["Area", "Bedrooms", "Age"]]
y= df["Price"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)

# %%
mse= mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 104705246.07894763

# %%
print("Intercept: ", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept:  -905116.2790697713
# Coefficients: [1.86046512e+02 2.37674419e+05 4.46511628e+04]

# %%
new_house= np.array([[2000,3,5]])
predicted_price= model.predict(new_house)
print(f"Predicted Price for the new house: ${predicted_price[0]:,.2f}")
# Out:
# Predicted Price for the new house: $403,255.81
# C:\Users\Ubaid\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
data= pd.read_csv(r"C:\Users\Ubaid\Desktop\Kaggle Datasets\Student_Performance.csv")

# %%
data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(127)

# %%
data = data.drop_duplicates()

# %%
data = data.dropna()

# %%
# Compute correlations
correlation = data.corr(numeric_only=True)
# Correlation with target 
print(correlation["Performance Index"].sort_values(ascending=False))
# Out:
# Performance Index                   1.000000
# Previous Scores                     0.915135
# Hours Studied                       0.375332
# Sleep Hours                         0.050352
# Sample Question Papers Practiced    0.043436
# Name: Performance Index, dtype: float64

# %%
x = data[['Previous Scores', 'Hours Studied', 'Sleep Hours']]
y = data['Performance Index']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("R² Score:", r2_score(y_test, y_pred))
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# R² Score: 0.9870234434085109
# Intercept: -32.83030434027441
# Coefficients: [1.01840325 2.85582142 0.46897274]

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Best fit line (45 degree line)
plt.xlabel('Actual Performance Index')
plt.ylabel('Predicted Performance Index')
plt.title('Actual vs Predicted Performance Index')
plt.grid(True)
plt.show()

# %%
#Gradient Descent
x= np.array([500,1000,1500,2500])
y=np.array([100,150,200,250,300])

# %%
x= x/1000

# %%
def hypothesis(x, theta0, theta1):
    return theta0 +theta1 *x

# %%
def compute_cost(x,y, theta0, theta1):
    m= len(x)
    predictions= hypothesis(x, theta0, theta1)
    return (1/ (2 * m)) *np.sum((predictions - y) ** 2)

# %%
#Gradient Descent
def gradient_descent(x,y, theta0,theta1,alpha, iterations):
    n= len(x)
    cost_history=[]
    for i in range(iterations):
        predictions= hypothesis(x, theta0, theta1)
        error= predictions - y

# %%
d_theta0= (1/ m) *np.sum(error)
d_theta1= (1/ m) * np.
